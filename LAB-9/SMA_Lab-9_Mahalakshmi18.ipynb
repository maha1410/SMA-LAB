# %% [markdown]
# # 205229118
# # Mahalakshmi S

# %% [markdown]
# ### Lab 9. Geocoding the LinkedIn Connections and visualising it on a map

# %% [markdown]
# In this lab you need to access your LinkedIn Connections and geocode the companies of the connections and visualise it on a map
#
# ### 1.	Retrieve the Connections data of your LinkedIn Profile from the previous lab and read it as a csv file using pandas module

# %%
import os
import csv

# Point this to your 'Connections.csv' file.
CSV_FILE = os.path.join('Connections1.csv')

csvReader = csv.DictReader(open(CSV_FILE), delimiter=',', quotechar='"')
contacts = [row for row in csvReader]

# %%
contacts
# Out:
# [{'First Name': 'Micro Media',
#   'Last Name': 'Films',
#   'Email Address': '',
#   'Company': 'Micro Media Films',
#   'Position': 'Owner',
#   'Connected On': '16-Sep-21'},
#  {'First Name': 'JENIFER',
#   'Last Name': 'T',
#   'Email Address': '',
#   'Company': 'TechLife Global',
#   'Position': '.NET Developer',
#   'Connected On': '16-Sep-21'},
#  {'First Name': 'Bhattacharya',
#   'Last Name': 'Shreya',
#   'Email Address': '',
#   'Company': 'The Sparks Foundation',
#   'Position': 'Human Resources Executive',
#   'Connected On': '16-Sep-21'},
#  {'First Name': 'Iswariya',
#   'Last Name': 'T',
#   'Email Address': '',
#   'Company': '',
#   'Position': '',
#   'Connected On': '16-Sep-21'},
#  {'First Name': 'PRIYAA  ',
#   'Last Name': 'LAKSHMI A S',
#   'Email Address': '',
#   'Company': '',
#   'Position': '',
#   'Connected On': '16-Sep-21'},
#  {'First Name': 'Yuvasri',
#   'Last Name': 'Matathammal',
#   'Email Address': '',
#   'Company': 'Geno Consulting Services Pvt Ltd.',
#   'Position': 'Senior Human Resources Recruiter',
#   'Connected On': '6-Jul-21'},
#  {'First Name': 'Eagle Eye',
#   'Last Name': 'IT Solutions',
#   'Email Address': '',
#   'Company': '',
#   'Position': '',
#   'Connected On': '30-Jun-21'},
#  {'First Name': 'Yuvashree',
#   'Last Name': 'M',
#   'Email Address': '',
#   'Company': '',
#   'Position': '',
#   'Connected On': '30-Jun-21'},
#  {'First Name': 'Franklin',
#   'Last Name': 'Solomon',
#   'Email Address': '',
#   'Company': '',
#   'Position': '',
#   'Connected On': '24-Jun-21'},
#  {'First Name': 'Jeniffer',
#   'Last Name': 'R',
#   'Email Address': '',
#   'Company': '',
#   'Position': '',
#   'Connected On': '24-Jun-21'},
#  {'First Name': 'karthikeyan',
#   'Last Name': 'raman',
#   'Email Address': '',
#   'Company': 'Tata Consultancy Services',
#   'Position': 'PLM Configuration Management',
#   'Connected On': '24-Jun-21'},
#  {'First Name': 'Nicholas',
#   'Last Name': 'Arockiaraj',
#   'Email Address': '',
#   'Company': '',
#   'Position': '',
#   'Connected On': '24-Jun-21'},
#  {'First Name': 'Jeevan',
#   'Last Name': 'Prasath',
#   'Email Address': '',
#   'Company': 'Unschool ',
#   'Position': 'unschool community champ',
#   'Connected On': '24-Jun-21'},
#  {'First Name': 'Shabana',
#   'Last Name': 'S',
#   'Email Address': '',
#   'Company': 'The Sparks Foundation',
#   'Position': 'Data Science and Business Analytics Intern',
#   'Connected On': '23-Jun-21'},
#  {'First Name': 'Sethuraman',
#   'Last Name': 'Periannan',
#   'Email Address': '',
#   'Company': '',
#   'Position': '',
#   'Connected On': '20-Jun-21'},
#  {'First Name': 'Rajkumar',
#   'Last Name': 'Kannan',
#   'Email Address': '',
#   'Company': 'Bishop Heber College, Tiruchirappalli - 620 017.',
#   'Position': 'Dean - Deanery International Relations',
#   'Connected On': '20-Jun-21'},
#  {'First Name': 'Aditya',
#   'Last Name': 'Vijay Vargiya',
#   'Email Address': '',
#   'Company': 'Internshala',
#   'Position': 'Data Science Training',
#   'Connected On': '20-Jun-21'},
#  {'First Name': 'Badrinath',
#   'Last Name': 'Madhivanan',
#   'Email Address': '',
#   'Company': 'Goeduhub Technologies',
#   'Position': 'Data Science and Machine Learning Trainee',
#   'Connected On': '20-Jun-21'},
#  {'First Name': 'Srinidhi',
#   'Last Name': 'S',
#   'Email Address': '',
#   'Company': 'Violet Tech',
#   'Position': 'Marketing Intern',
#   'Connected On': '20-Jun-21'},
#  {'First Name': 'Arzoo',
#   'Last Name': 'Sah',
#   'Email Address': '',
#   'Company': '',
#   'Position': '',
#   'Connected On': '20-Jun-21'},
#  {'First Name': 'SABARINATH',
#   'Last Name': 'PALANI',
#   'Email Address': '',
#   'Company': 'Adsdunia Private Limited',
#   'Position': 'flutter ui developer',
#   'Connected On': '11-Jun-21'},
#  {'First Name': 'ANUB ',
#   'Last Name': 'DANIEL',
#   'Email Address': '',
#   'Company': '',
#   'Position': '',
#   'Connected On': '11-Jun-21'},
#  {'First Name': 'vezhaventhan',
#   'Last Name': 'n',
#   'Email Address': '',
#   'Company': 'nil',
#   'Position': 'Data Scientist',
#   'Connected On': '11-Jun-21'},
#  {'First Name': 'Sharvesh',
#   'Last Name': 'Waran',
#   'Email Address': '',
#   'Company': 'Bishop Heber College',
#   'Position': 'Student',
#   'Connected On': '10-Jun-21'},
#  {'First Name': 'Rohan',
#   'Last Name': 'R',
#   'Email Address': '',
#   'Company': 'Bishop Heber College, Tiruchirappalli - 620 017.',
#   'Position': 'Postgraduate Student',
#   'Connected On': '9-Jun-21'},
#  {'First Name': 'Arunkumar',
#   'Last Name': 'A',
#   'Email Address': '',
#   'Company': '',
#   'Position': '',
#   'Connected On': '9-Jun-21'},
#  {'First Name': 'Ragez',
#   'Last Name': 'Prashant',
#   'Email Address': '',
#   'Company': 'ETIQU',
#   'Position': 'Business Professional',
#   'Connected On': '9-Jun-21'},
#  {'First Name': 'KARAN',
#   'Last Name': 'R',
#   'Email Address': '',
#   'Company': '',
#   'Position': '',
#   'Connected On': '9-Jun-21'},
#  {'First Name': 'Albin',
#   'Last Name': 'S',
#   'Email Address': '',
#   'Company': '',
#   'Position': '',
#   'Connected On': '8-Jun-21'},
#  {'First Name': 'Karthik',
#   'Last Name': 'V A',
#   'Email Address': '',
#   'Company': '',
#   'Position': '',
#   'Connected On': '8-Jun-21'},
#  {'First Name': 'SIVARAJ',
#   'Last Name': 'D',
#   'Email Address': '',
#   'Company': '',
#   'Position': '',
#   'Connected On': '8-Jun-21'},
#  {'First Name': 'Ram',
#   'Last Name': 'Prakash',
#   'Email Address': '',
#   'Company': 'HCL Technologies',
#   'Position': 'Customer Service Executive',
#   'Connected On': '8-Jun-21'},
#  {'First Name': 'Frastlin',
#   'Last Name': 'J',
#   'Email Address': '',
#   'Company': '',
#   'Position': '',
#   'Connected On': '8-Jun-21'},
#  {'First Name': 'rene',
#   'Last Name': 'irakoze ',
#   'Email Address': '',
#   'Company': 'The Sparks Foundation',
#   'Position': 'Data Science and business analytics intern',
#   'Connected On': '8-Jun-21'},
#  {'First Name': 'Nirmal',
#   'Last Name': 'kumar.G',
#   'Email Address': '',
#   'Company': '',
#   'Position': '',
#   'Connected On': '8-Jun-21'},
#  {'First Name': 'Selvan',
#   'Last Name': 'Kumar',
#   'Email Address': '',
#   'Company': 'The Sparks Foundation',
#   'Position': 'Data Science Intern',
#   'Connected On': '8-Jun-21'},
#  {'First Name': 'Shabana ',
#   'Last Name': 'S',
#   'Email Address': '',
#   'Company': '',
#   'Position': '',
#   'Connected On': '8-Jun-21'},
#  {'First Name': 'SANDHYA',
#   'Last Name': 'S',
#   'Email Address': '',
#   'Company': 'LetsGrowMore',
#   'Position': 'Data Science ',
#   'Connected On': '7-Jun-21'},
#  {'First Name': 'Keerthana',
#   'Last Name': 'S',
#   'Email Address': '',
#   'Company': '',
#   'Position': '',
#   'Connected On': '6-Jun-21'},
#  {'First Name': 'Howsik',
#   'Last Name': 'T',
#   'Email Address': '',
#   'Company': 'Digiit Business Services',
#   'Position': 'Graphic Web Designer',
#   'Connected On': '6-Jun-21'},
#  {'First Name': 'Viveka',
#   'Last Name': 'Balaji',
#   'Email Address': '',
#   'Company': 'The Sparks Foundation',
#   'Position': 'Data science and business analytics intern',
#   'Connected On': '6-Jun-21'},
#  {'First Name': 'Mohamed',
#   'Last Name': 'Sahim',
#   'Email Address': '',
#   'Company': 'The Sparks Foundation',
#   'Position': 'Data Science and Business Analytics',
#   'Connected On': '5-Jun-21'},
#  {'First Name': 'Jayasurya',
#   'Last Name': 'V',
#   'Email Address': '',
#   'Company': 'Actify Data Labs',
#   'Position': 'Data Analyst',
#   'Connected On': '5-Jun-21'},
#  {'First Name': 'Vissweswaran',
#   'Last Name': 'C',
#   'Email Address': '',
#   'Company': 'The Sparks Foundation',
#   'Position': 'Data Science and Business Analystics Intern',
#   'Connected On': '5-Jun-21'},
#  {'First Name': 'Maheshvaran',
#   'Last Name': 'S',
#   'Email Address': '',
#   'Company': '',
#   'Position': '',
#   'Connected On': '5-Jun-21'},
#  {'First Name': 'Pranietha',
#   'Last Name': 'V C',
#   'Email Address': '',
#   'Company': 'Cognizant',
#   'Position': 'Programmer traniee',
#   'Connected On': '5-Jun-21'},
#  {'First Name': 'Bharathwin',
#   'Last Name': 'MA',
#   'Email Address': '',
#   'Company': 'The Sparks Foundation',
#   'Position': 'Data Science and Business Analytics - Internship',
#   'Connected On': '5-Jun-21'},
#  {'First Name': 'VIVIYAN',
#   'Last Name': 'RICHARDS',
#   'Email Address': '',
#   'Company': '',
#   'Position': '',
#   'Connected On': '5-Jun-21'},
#  {'First Name': 'Hariharasudhan',
#   'Last Name': 'D',
#   'Email Address': '',
#   'Company': '',
#   'Position': '',
#   'Connected On': '5-Jun-21'},
#  {'First Name': 'Hari',
#   'Last Name': 'Prasanna',
#   'Email Address': '',
#   'Company': 'Bishop Heber College, Tiruchirappalli - 620 017.',
#   'Position': 'Postgraduate Student',
#   'Connected On': '5-Jun-21'},
#  {'First Name': 'Janani',
#   'Last Name': 'Selvaraj PhD',
#   'Email Address': '',
#   'Company': 'Bishop Heber College, Tiruchirappalli - 620 017.',
#   'Position': 'Guest Lecturer',
#   'Connected On': '5-Jun-21'},
#  {'First Name': 'pavithra',
#   'Last Name': 'pandiyan',
#   'Email Address': '',
#   'Company': 'Nint',
#   'Position': 'Trainee',
#   'Connected On': '5-Jun-21'},
#  {'First Name': 'Rithic',
#   'Last Name': 'Arputharaj U',
#   'Email Address': '',
#   'Company': 'The Sparks Foundation',
#   'Position': 'Data Science and Business analytics intern',
#   'Connected On': '2-Jun-21'},
#  {'First Name': 'LALITH',
#   'Last Name': 'AKASH',
#   'Email Address': '',
#   'Company': '',
#   'Position': '',
#   'Connected On': '2-Jun-21'},
#  {'First Name': 'Deepak',
#   'Last Name': 'R',
#   'Email Address': '',
#   'Company': 'The Sparks Foundation',
#   'Position': ' Data Science and Business Analystics Intern ',
#   'Connected On': '2-Jun-21'},
#  {'First Name': 'Reshma',
#   'Last Name': 'R S',
#   'Email Address': '',
#   'Company': 'The Sparks Foundation',
#   'Position': 'Data Science and Business Analytics Intern',
#   'Connected On': '24-May-21'},
#  {'First Name': 'Ravinathan',
#   'Last Name': 'R',
#   'Email Address': '',
#   'Company': 'KPMG India',
#   'Position': 'Data Analytics consulting virtual internship',
#   'Connected On': '13-May-21'}]

# %% [markdown]
# ### 2.Apply transformation to the Company feature by removing the company related suffixes

# %%
# !pip install prettytable
# Out:
# Requirement already satisfied: prettytable in c:\users\mahalakshmi\anaconda3\lib\site-packages (2.2.0)
# Requirement already satisfied: wcwidth in c:\users\mahalakshmi\anaconda3\lib\site-packages (from prettytable) (0.2.5)

# %%
from prettytable import PrettyTable # pip install prettytable
from collections import Counter
from operator import itemgetter

# Define a set of transforms that converts the first item
# to the second item. Here, we're simply handling some
# commonly known abbreviations, stripping off common suffixes, 
# etc.

transforms = [(', Inc.', ''), (', Inc', ''), (', LLC', ''), (', LLP', ''),
               (' LLC', ''), (' Inc.', ''), (' Inc', '')]

companies = [c['Company'].strip() for c in contacts if c['Company'].strip() != '']

for i, _ in enumerate(companies):
    for transform in transforms:
        companies[i] = companies[i].replace(*transform)

pt = PrettyTable(field_names=['Company', 'Freq'])
pt.align = 'l'
c = Counter(companies)

[pt.add_row([company, freq]) for (company, freq) in sorted(c.items(), key=itemgetter(1), reverse=True) if freq > 1]

print(pt)
# Out:
# +--------------------------------------------------+------+
# | Company                                          | Freq |
# +--------------------------------------------------+------+
# | The Sparks Foundation                            | 11   |
# | Bishop Heber College, Tiruchirappalli - 620 017. | 4    |
# +--------------------------------------------------+------+

# %%
transforms = [
    ('Sr.', 'Senior'),
    ('Sr', 'Senior'),
    ('Jr.', 'Junior'),
    ('Jr', 'Junior'),
    ('CEO', 'Chief Executive Officer'),
    ('COO', 'Chief Operating Officer'),
    ('CTO', 'Chief Technology Officer'),
    ('CFO', 'Chief Finance Officer'),
    ('VP', 'Vice President'),
    ]

# Read in a list of titles and split apart
# any combined titles like "President/CEO."
# Other variations could be handled as well, such
# as "President & CEO", "President and CEO", etc.

titles = []
for contact in contacts:
    titles.extend([t.strip() for t in contact['Position'].split('/')
                  if contact['Position'].strip() != ''])

# Replace common/known abbreviations

for i, _ in enumerate(titles):
    for transform in transforms:
        titles[i] = titles[i].replace(*transform)

# Print out a table of titles sorted by frequency

pt = PrettyTable(field_names=['Job Title', 'Freq'])
pt.align = 'l'
c = Counter(titles)
[pt.add_row([title, freq]) 
 for (title, freq) in sorted(c.items(), key=itemgetter(1), reverse=True) 
     if freq > 1]
print(pt)

# Print out a table of tokens sorted by frequency

tokens = []
for title in titles:
    tokens.extend([t.strip(',') for t in title.split()])
pt = PrettyTable(field_names=['Token', 'Freq'])
pt.align = 'l'
c = Counter(tokens)
[pt.add_row([token, freq]) 
 for (token, freq) in sorted(c.items(), key=itemgetter(1), reverse=True) 
     if freq > 1 and len(token) > 2]
print(pt)
# Out:
# +---------------------------------------------+------+
# | Job Title                                   | Freq |
# +---------------------------------------------+------+
# | Data Science and Business Analytics Intern  | 2    |
# | Postgraduate Student                        | 2    |
# | Data Science and Business Analystics Intern | 2    |
# +---------------------------------------------+------+
# +--------------+------+
# | Token        | Freq |
# +--------------+------+
# | Data         | 16   |
# | Science      | 12   |
# | and          | 10   |
# | Business     | 8    |
# | Intern       | 6    |
# | Analytics    | 5    |
# | Student      | 3    |
# | analytics    | 3    |
# | intern       | 3    |
# | Human        | 2    |
# | Resources    | 2    |
# | Executive    | 2    |
# | Trainee      | 2    |
# | Postgraduate | 2    |
# | business     | 2    |
# | Analystics   | 2    |
# +--------------+------+

# %% [markdown]
# ### 3.	Geocode the companies and get the latitude longitude values of the organisations using opencage module

# %%
# !pip install opencage
# Out:
# Requirement already satisfied: opencage in c:\users\mahalakshmi\anaconda3\lib\site-packages (2.0.0)
# Requirement already satisfied: backoff>=1.10.0 in c:\users\mahalakshmi\anaconda3\lib\site-packages (from opencage) (1.11.1)
# Requirement already satisfied: Requests>=2.2.0 in c:\users\mahalakshmi\anaconda3\lib\site-packages (from opencage) (2.25.1)
# Requirement already satisfied: pyopenssl>=0.15.1 in c:\users\mahalakshmi\anaconda3\lib\site-packages (from opencage) (20.0.1)
# Requirement already satisfied: six>=1.5.2 in c:\users\mahalakshmi\anaconda3\lib\site-packages (from pyopenssl>=0.15.1->opencage) (1.15.0)
# Requirement already satisfied: cryptography>=3.2 in c:\users\mahalakshmi\anaconda3\lib\site-packages (from pyopenssl>=0.15.1->opencage) (3.4.7)
# Requirement already satisfied: cffi>=1.12 in c:\users\mahalakshmi\anaconda3\lib\site-packages (from cryptography>=3.2->pyopenssl>=0.15.1->opencage) (1.14.5)
# Requirement already satisfied: pycparser in c:\users\mahalakshmi\anaconda3\lib\site-packages (from cffi>=1.12->cryptography>=3.2->pyopenssl>=0.15.1->opencage) (2.20)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\mahalakshmi\anaconda3\lib\site-packages (from Requests>=2.2.0->opencage) (1.26.4)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\mahalakshmi\anaconda3\lib\site-packages (from Requests>=2.2.0->opencage) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\mahalakshmi\anaconda3\lib\site-packages (from Requests>=2.2.0->opencage) (2020.12.5)
# Requirement already satisfied: chardet<5,>=3.0.2 in c:\users\mahalakshmi\anaconda3\lib\site-packages (from Requests>=2.2.0->opencage) (4.0.0)

# %%
from opencage.geocoder import OpenCageGeocode #pip install opencage
key = '081afd6c6215402cb8625e6a3c722f74'
geocoder = OpenCageGeocode(key)
query = "O'Reilly Media"
result = geocoder.geocode(query)
print(result)
# Out:
# [{'annotations': {'DMS': {'lat': "39° 55' 0.40800'' N", 'lng': "75° 23' 15.68400'' W"}, 'FIPS': {'county': '42045', 'state': '42'}, 'MGRS': '18SVK6686618592', 'Maidenhead': 'FM29hw30la', 'Mercator': {'x': -8392119.263, 'y': 4826433.122}, 'OSM': {'note_url': 'https://www.openstreetmap.org/note/new#map=17/39.91678/-75.38769&layers=N', 'url': 'https://www.openstreetmap.org/?mlat=39.91678&mlon=-75.38769#map=17/39.91678/-75.38769'}, 'UN_M49': {'regions': {'AMERICAS': '019', 'NORTHERN_AMERICA': '021', 'US': '840', 'WORLD': '001'}, 'statistical_groupings': ['MEDC']}, 'callingcode': 1, 'currency': {'alternate_symbols': ['US$'], 'decimal_mark': '.', 'disambiguate_symbol': 'US$', 'html_entity': '$', 'iso_code': 'USD', 'iso_numeric': '840', 'name': 'United States Dollar', 'smallest_denomination': 1, 'subunit': 'Cent', 'subunit_to_unit': 100, 'symbol': '$', 'symbol_first': 1, 'thousands_separator': ','}, 'flag': '🇺🇸', 'geohash': 'dr47hd8k5e059dershtq', 'qibla': 57.59, 'roadinfo': {'drive_on': 'right', 'speed_in': 'mph'}, 'sun': {'rise': {'apparent': 1632048480, 'astronomical': 1632043020, 'civil': 1632046860, 'nautical': 1632044940}, 'set': {'apparent': 1632092520, 'astronomical': 1632011520, 'civil': 1632094140, 'nautical': 1632009600}}, 'timezone': {'name': 'America/New_York', 'now_in_dst': 1, 'offset_sec': -14400, 'offset_string': '-0400', 'short_name': 'EDT'}, 'what3words': {'words': 'vision.sunset.muddy'}}, 'bounds': {'northeast': {'lat': 39.929567, 'lng': -75.378087}, 'southwest': {'lat': 39.911963, 'lng': -75.399685}}, 'components': {'ISO_3166-1_alpha-2': 'US', 'ISO_3166-1_alpha-3': 'USA', '_category': 'place', '_type': 'city', 'continent': 'North America', 'country': 'United States of America', 'country_code': 'us', 'county': 'Delaware County', 'state': 'Pennsylvania', 'state_code': 'PA', 'town': 'Media'}, 'confidence': 8, 'formatted': 'Media, Pennsylvania, United States of America', 'geometry': {'lat': 39.91678, 'lng': -75.38769}}]

# %%
result
# Out:
# [{'annotations': {'DMS': {'lat': "39° 55' 0.40800'' N",
#     'lng': "75° 23' 15.68400'' W"},
#    'FIPS': {'county': '42045', 'state': '42'},
#    'MGRS': '18SVK6686618592',
#    'Maidenhead': 'FM29hw30la',
#    'Mercator': {'x': -8392119.263, 'y': 4826433.122},
#    'OSM': {'note_url': 'https://www.openstreetmap.org/note/new#map=17/39.91678/-75.38769&layers=N',
#     'url': 'https://www.openstreetmap.org/?mlat=39.91678&mlon=-75.38769#map=17/39.91678/-75.38769'},
#    'UN_M49': {'regions': {'AMERICAS': '019',
#      'NORTHERN_AMERICA': '021',
#      'US': '840',
#      'WORLD': '001'},
#     'statistical_groupings': ['MEDC']},
#    'callingcode': 1,
#    'currency': {'alternate_symbols': ['US$'],
#     'decimal_mark': '.',
#     'disambiguate_symbol': 'US$',
#     'html_entity': '$',
#     'iso_code': 'USD',
#     'iso_numeric': '840',
#     'name': 'United States Dollar',
#     'smallest_denomination': 1,
#     'subunit': 'Cent',
#     'subunit_to_unit': 100,
#     'symbol': '$',
#     'symbol_first': 1,
#     'thousands_separator': ','},
#    'flag': '🇺🇸',
#    'geohash': 'dr47hd8k5e059dershtq',
#    'qibla': 57.59,
#    'roadinfo': {'drive_on': 'right', 'speed_in': 'mph'},
#    'sun': {'rise': {'apparent': 1632048480,
#      'astronomical': 1632043020,
#      'civil': 1632046860,
#      'nautical': 1632044940},
#     'set': {'apparent': 1632092520,
#      'astronomical': 1632011520,
#      'civil': 1632094140,
#      'nautical': 1632009600}},
#    'timezone': {'name': 'America/New_York',
#     'now_in_dst': 1,
#     'offset_sec': -14400,
#     'offset_string': '-0400',
#     'short_name': 'EDT'},
#    'what3words': {'words': 'vision.sunset.muddy'}},
#   'bounds': {'northeast': {'lat': 39.929567, 'lng': -75.378087},
#    'southwest': {'lat': 39.911963, 'lng': -75.399685}},
#   'components': {'ISO_3166-1_alpha-2': 'US',
#    'ISO_3166-1_alpha-3': 'USA',
#    '_category': 'place',
#    '_type': 'city',
#    'continent': 'North America',
#    'country': 'United States of America',
#    'country_code': 'us',
#    'county': 'Delaware County',
#    'state': 'Pennsylvania',
#    'state_code': 'PA',
#    'town': 'Media'},
#   'confidence': 8,
#   'formatted': 'Media, Pennsylvania, United States of America',
#   'geometry': {'lat': 39.91678, 'lng': -75.38769}}]

# %% [markdown]
# ### 4.	Visualise the connections on a map and observe your network

# %%
from opencage.geocoder import OpenCageGeocode
key = "081afd6c6215402cb8625e6a3c722f74"
geocoder = OpenCageGeocode(key)
address='First Name'
result = geocoder.geocode(address, no_annotations="1")  
result[0]['geometry']
# Out:
# {'lat': 52.5477127, 'lng': -1.935611}

# %%
import pandas as pd
data=pd.read_csv('Connections1.csv')
data.head(10)
# Out:
#      First Name     Last Name  Email Address  \
# 0   Micro Media         Films            NaN
# 1       JENIFER             T            NaN
# 2  Bhattacharya        Shreya            NaN
# 3      Iswariya             T            NaN
# 4      PRIYAA     LAKSHMI A S            NaN
# 5       Yuvasri   Matathammal            NaN
# 6     Eagle Eye  IT Solutions            NaN
# 7     Yuvashree             M            NaN
# 8      Franklin       Solomon            NaN
# 9      Jeniffer             R            NaN
#
#                              Company                          Position  \
# 0                  Micro Media Films                             Owner
# 1                    TechLife Global                    .NET Developer
# 2              The Sparks Foundation         Human Resources Executive
# 3                                NaN                               NaN
# 4                                NaN                               NaN
# 5  Geno Consulting Services Pvt Ltd.  Senior Human Resources Recruiter
# 6                                NaN                               NaN
# 7                                NaN                               NaN
# 8                                NaN                               NaN
# 9                                NaN                               NaN
#
#   Connected On
# 0    16-Sep-21
# 1    16-Sep-21
# 2    16-Sep-21
# 3    16-Sep-21
# 4    16-Sep-21
# 5     6-Jul-21
# 6    30-Jun-21
# 7    30-Jun-21
# 8    24-Jun-21
# 9    24-Jun-21

# %%
addresses = data["Connected On"].values.tolist()
key = "081afd6c6215402cb8625e6a3c722f74"
geocoder = OpenCageGeocode(key)
latitudes = []
longitudes = []
for address in addresses: 
    result = geocoder.geocode(address, no_annotations="1")  
    
    if result and len(result):  
        longitude = result[0]["geometry"]["lng"]  
        latitude = result[0]["geometry"]["lat"] 
    else:  
        longitude = "N/A"  
        latitude = "N/A"     
    
    latitudes.append(latitude) 
    longitudes.append(longitude)

# %%
data["latitudes"] = latitudes
data["longitudes"] = longitudes
data.head(5)
# Out:
#      First Name    Last Name  Email Address                Company  \
# 0   Micro Media        Films            NaN      Micro Media Films
# 1       JENIFER            T            NaN        TechLife Global
# 2  Bhattacharya       Shreya            NaN  The Sparks Foundation
# 3      Iswariya            T            NaN                    NaN
# 4      PRIYAA    LAKSHMI A S            NaN                    NaN
#
#                     Position Connected On  latitudes  longitudes
# 0                      Owner    16-Sep-21  51.017593   20.221634
# 1             .NET Developer    16-Sep-21  51.017593   20.221634
# 2  Human Resources Executive    16-Sep-21  51.017593   20.221634
# 3                        NaN    16-Sep-21  51.017593   20.221634
# 4                        NaN    16-Sep-21  51.017593   20.221634

# %%
# !pip install folium
# Out:
# Requirement already satisfied: folium in c:\users\mahalakshmi\anaconda3\lib\site-packages (0.12.1)
# Requirement already satisfied: branca>=0.3.0 in c:\users\mahalakshmi\anaconda3\lib\site-packages (from folium) (0.4.2)
# Requirement already satisfied: requests in c:\users\mahalakshmi\anaconda3\lib\site-packages (from folium) (2.25.1)
# Requirement already satisfied: jinja2>=2.9 in c:\users\mahalakshmi\anaconda3\lib\site-packages (from folium) (2.11.3)
# Requirement already satisfied: numpy in c:\users\mahalakshmi\anaconda3\lib\site-packages (from folium) (1.19.5)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\mahalakshmi\anaconda3\lib\site-packages (from jinja2>=2.9->folium) (1.1.1)
# Requirement already satisfied: chardet<5,>=3.0.2 in c:\users\mahalakshmi\anaconda3\lib\site-packages (from requests->folium) (4.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\mahalakshmi\anaconda3\lib\site-packages (from requests->folium) (2020.12.5)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\mahalakshmi\anaconda3\lib\site-packages (from requests->folium) (1.26.4)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\mahalakshmi\anaconda3\lib\site-packages (from requests->folium) (2.10)

# %%
import folium
from folium.plugins import FastMarkerCluster

# %%
folium_map= folium.Map(location=[51.017593,20.221634],zoom_start=4.4,control_scale=True)
FastMarkerCluster(data[['latitudes', 'longitudes']].values.tolist()).add_to(folium_map)
folium.LayerControl().add_to(folium_map) 
for row in data.iterrows():
    row=row[1]
    folium.CircleMarker(location=(row["latitudes"],
                                  row["longitudes"]),
                        radius= 10,
                        color="#007849",
                        popup=row['Company'],
                        fill=False).add_to(folium_map)
    
folium_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_5752310240a54fc3bfad2b7b1bc901a6%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css%22/%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_5752310240a54fc3bfad2b7b1bc901a6%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3 ...
